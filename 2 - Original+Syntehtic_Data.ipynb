# %% [markdown]
# # Analysis of the synthetic dataset - Creation of the merged dataset

# %%
import pandas as pd
import numpy as np

# %%
synthetic_data = pd.read_csv("Breast Cancer Dataset Augmentation_synthetic.csv", sep=';')
original_data = pd.read_csv("data.csv")

# %%
synthetic_data.shape
# Out:
# (398, 32)

# %%
original_data.shape
# Out:
# (569, 33)

# %%
original_data.head(5)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
synthetic_data.head(5)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean   area_mean  \
# 0     87118         M    15.152704     12.068350      102.722403  695.202960
# 1    914356         B    16.646851     15.688377      105.865353  853.481867
# 2  87904832         B    14.558657     13.326831       94.193746  656.390375
# 3    908099         B    14.860802     14.974002       96.398682  684.604196
# 4   8910659         B    10.051197     16.644878       66.835548  321.153441
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0         0.123640          0.166060        0.213416             0.101883
# 1         0.093851          0.065813        0.064692             0.059756
# 2         0.098687          0.080458        0.061317             0.055386
# 3         0.081403          0.082000        0.051153             0.028379
# 4         0.106800          0.148488        0.334884             0.094945
#
# ...

# %%
original_data = original_data.drop(['Unnamed: 32'], axis=1)
original_data.shape
# Out:
# (569, 32)

# %%
merged_data = pd.concat([original_data, synthetic_data], axis=0)

# %%
merged_data.shape
# Out:
# (967, 32)

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 967 entries, 0 to 397
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       967 non-null    int64
#  1   diagnosis                967 non-null    object
#  2   radius_mean              967 non-null    float64
#  3   texture_mean             967 non-null    float64
#  4   perimeter_mean           967 non-null    float64
#  5   area_mean                967 non-null    float64
#  6   smoothness_mean          967 non-null    float64
#  7   compactness_mean         967 non-null    float64
#  8   concavity_mean           967 non-null    float64
#  9   concave points_mean      967 non-null    float64
#  10  symmetry_mean            967 non-null    float64
#  11  fractal_dimension_mean   967 non-null    float64
#  12  radius_se                967 non-null    float64
#  13  texture_se               967 non-null    float64
# ...

# %%
description = merged_data.drop(['id'], axis=1)
description = description.describe().transpose()
description
# Out:
#                          count        mean         std         min  \
# radius_mean              967.0   14.154556    3.560252    6.981000
# texture_mean             967.0   19.351195    4.318068    9.710000
# perimeter_mean           967.0   92.136098   24.572033   43.790000
# area_mean                967.0  657.510218  357.091387  143.500000
# smoothness_mean          967.0    0.096146    0.014341    0.052630
# compactness_mean         967.0    0.104440    0.054382    0.019380
# concavity_mean           967.0    0.089787    0.081105    0.000000
# concave points_mean      967.0    0.049363    0.039571    0.000000
# symmetry_mean            967.0    0.181223    0.027357    0.106000
# fractal_dimension_mean   967.0    0.062754    0.007221    0.049960
# radius_se                967.0    0.406843    0.276733    0.111500
# texture_se               967.0    1.215931    0.550687    0.360200
# perimeter_se             967.0    2.871642    2.020989    0.757000
# ...

# %%
description.to_html('merged_data_stats.html')

# %%
merged_data.to_csv('merged_dataframe.csv', index=False)
